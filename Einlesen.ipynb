# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set(style="darkgrid")

# CSV einlesen (Achtung keine '/' in den Spaltenüberschriften wegen späterem Namen)
# geht davon aus, dass keine Fehler in der Datei sind und alle Felder richtig gefüllt
# zum Überprüfen dien Notebooks LPS_first bzw. ARC_first nutzen

anzahl_header_zeilen=0

df = pd.read_csv('input/EKB.csv', sep=';', 
                 header=anzahl_header_zeilen, 
                 usecols=[0,1,2,3,4,5], 
                 parse_dates=[3,4,5],
                 dayfirst=True,  #für deutsches Datumsformat
                 skip_blank_lines = False,
                 encoding='iso8859_15')

df.columns = ['PK', 'titel', 'art', 'next', 'input',  'out']
 
print "Anzahl Zeilen eingelesen", len(df.index)    
    
#Zeilen wegschmeissen, wenn mind. 2 Felder NaN sind (aka Leerzeilen)
df = df.dropna(thresh=2)
print "Anzahl 'gültige' Zeilen ", len(df.index)

print "Erste gültige Zeile\n", df[:1]
print "\nLetzte gültige Zeile\n",df[-1:]

print "\nDatatypes\n", df.dtypes

von=(min(df.input))
von=von.strftime('%d.%m.%Y')


bis=(max(df.out))
bis=bis.strftime('%d.%m.%Y')
print "Daten von", von, "bis", bis

# nimm nur Zeilen, in denen out gesetzt ist
#df = df[df.out.notnull()]

# Wenn input leer ist, kopiere den Wert aus next
df.input[df.input.isnull()] = df.next[df.input.isnull()]

feiertage = ['2018-10-03', # Tag der Einheit
             '2018-11-01', # Allerheiligen
             '2018-12-24', # Heiligabend
             '2018-12-25', # Weihnachten
             '2018-12-26', # Weihnachten
             '2018-12-31', # Silvester
             '2019-01-01', # Neujahr
             '2019-02-28', # Wieverfastelovend
             '2019-03-04', # Rosenmontag
             '2019-04-19', # Karfreitag
             '2019-04-22', # Ostermontag
             '2019-05-01', # 1. Mai
             '2019-05-30', # Christi Himmelfahrt
             '2019-06-10', # Pfingst-Montag
             '2019-06-20'  # Fronleichnam
            ]

#neue Spalte "dauer"

col = np.zeros(len(df), int) 
for i in range (0, len(df)):
    if pd.isna(oo[i]):
        col[i] = 10000
    else:
        col[i] = np.busday_count(ii[i], oo[i], holidays=feiertage)+1
#end for i in range
    
df['dauer'] = col

# Aufruf mit Columns in den out gesetzt ist: dauer_calc(df[~pd.isna(df.out)])

print df.dauer

print "Einträge mit negativer Dauer", df[ df.dauer < 1 ]

#df[df.out.isnull()]
# Out:
# Anzahl Zeilen eingelesen 141
# Anzahl 'gültige' Zeilen  124
# Erste gültige Zeile
#     PK                                              titel          art  \
# 0  200  Klärung Partneranlage aus CRM für Schaden ohne AD  Regelarbeit
#
#         next      input        out
# 0 2019-05-20 2019-05-20 2019-05-28
#
# Letzte gültige Zeile
#       PK                        titel             art       next input out
# 123  323  NFA-Dokument auf NVP prüfen  Extern geplant 2019-08-13   NaT NaT
#
# Datatypes
# PK                int64
# titel            object
# art              object
# next     datetime64[ns]
# input    datetime64[ns]
# out      datetime64[ns]
# dtype: object
# Daten von 11.02.2019 bis 13.08.2019
# 0          7
# 1         21
# 2         10
# 3          3
# 4         37
# 5          5
# 6          5
# 7         22
# 8          3
# 9          1
# 10        12
# 11        22
# 12         1
# 13        49
# 14        11
# 15         5
# 16         6
# 17        22
# 18         5
# 19        30
# 20         7
# 21        66
# 22        20
# 23        11
# 24        44
# 25        75
# 26         1
# 27        50
# 28        47
# 29        51
#        ...
# 94         8
# 95     10000
# 96         6
# 97         1
# 98         4
# 99         9
# 100    10000
# 101    10000
# 102    10000
# 103       14
# 104    10000
# 105        2
# 106        2
# 107    10000
# 108    10000
# 109    10000
# 110    10000
# 111    10000
# 112        1
# 113        1
# 114        8
# 115    10000
# 116    10000
# 117    10000
# 118    10000
# 119        3
# 120    10000
# 121    10000
# 122    10000
# 123    10000
# Name: dauer, Length: 124, dtype: int64
# Einträge mit negativer Dauer Empty DataFrame
# Columns: [PK, titel, art, next, input, out, dauer]
# Index: []
